# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Importações

# %%
# Dependências necessárias
# !pip install statsmodels

# Bibliotecas
import numpy as np  # linear algebra
import pandas as pd # processamento de dados

import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Bases de dados
df = pd.read_csv('world-data-2023.csv')
continents_df = pd.read_csv('continentes.csv', sep=';')

# %% [markdown]
# ## 1 - Carregando e compreendendo os dados

# %% [markdown]
# As colunas desse dataset são:
#
# | Inglês  | Português  | Descrição |
# | ------- | -------- | -------- |
# | Country   | País    |Nome do país |
# | Density (P/Km2)   | Densidade    |Densidade populacional medida em pessoas por quilômetro quadrado |
# | Abbreviation   | Abreviatura    |Abreviatura ou código que representa o país |
# | Agricultural Land (%)   | Terra Agrícola    |Percentagem da área de terra utilizada para fins agrícolas |
# | Land Area (Km2)   | Área Terrestre    |Área total do país em quilômetros quadrados |
# | Armed Forces Size   | Tamanho das Forças Armadas    |Tamanho das forças armadas do país |
# | Birth Rate   | Taxa de natalidade    |Número de nascimentos por 1 |000 habitantes por ano |
# | Calling Code   | Código de chamada    |Código de chamada internacional para o país |
# | Capital/Major City   | Capital/Cidade Principal    |Nome da capital ou cidade principal |
# | CO2 Emissions   | Emissões de CO2    |Emissões de dióxido de carbono em toneladas |
# | CPI   | IPC   | Índice de Preços ao Consumidor, uma medida de inflação e poder de compra |
# | CPI Change (%)   | Variação do IPC    |Variação percentual do Índice de Preços ao Consumidor em relação ao ano anterior |
# | Currency_Code   | Códico_moeda    |Código da moeda utilizada no país |
# | Fertility Rate   | Taxa de fertilidade    |Número médio de filhos nascidos de uma mulher durante sua vida |
# | Forested Area (%)   | Área Florestada    |Porcentagem de área coberta por florestas |
# | Gasoline_Price   | Preco_Gasolina   |Preço da gasolina por litro em moeda local |
# | GDP   | PIB    |Produto Interno Bruto, valor total dos bens e serviços produzidos no país |
# | Gross Primary Education Enrollment (%)   | Matrícula bruta no ensino primário    |Taxa bruta de matrícula no ensino primário |
# | Gross Tertiary Education Enrollment (%)   | Matrícula bruta no ensino superior    |Taxa bruta de matrícula no ensino superior |
# | Infant Mortality   | Mortalidade Infantil    |Número de mortes por 1 |000 nascidos vivos antes de completar um ano de idade |
# | Largest City   | Maior Cidade    |Nome da maior cidade do país |
# | Life Expectancy   | Expectativa de vida    |Número médio de anos que se espera que um recém-nascido viva |
# | Maternal Mortality Ratio   | Razão de Mortalidade Materna    |Número de mortes maternas por 100 |000 nascidos vivos |
# | Minimum Wage   | Salário Mínimo    |Nível do salário mínimo em moeda local |
# | Official Language   | Idioma Oficial    |Língua(s) oficial(is) falada(s) no país |
# | Out of Pocket Health Expenditure (%)   | Despesas Desembolsadas com Saúde    |Percentagem das despesas totais com saúde pagas diretamente pelos indivíduos |
# | Physicians per Thousand   | Médicos por Mil    |Número de médicos por mil pessoas |
# | Population   | População    |População total do país |
# | Population:  Labor Force Participation (%)   | População:	 Participação na Força de Trabalho   | Porcentagem da população que faz parte da força de trabalho |
# | Tax Revenue (%)   | Receita Fiscal    |Receita tributária em percentagem do PIB |
# | Total Tax Rate   | Taxa Total de Imposto    |Carga tributária global como percentagem dos lucros comerciais |
# | Unemployment Rate   | Taxa de Desemprego    |Porcentagem da força de trabalho que está desempregada |
# | Urban Population   | População Urbana    |Porcentagem da população que vive em áreas urbanas |
# | Latitude   | Latitude    |Coordenada de latitude da localização do país |
# | Longitude   | Longitude    |Coordenada de longitude da localização do país |

# %%
# Para facilitar a leitura é realizado transposição da tabela
df.head().T
# Out:
#                                                           0                 1  \
# Country                                         Afghanistan           Albania
# Density(P/Km2)                                           60               105
# Abbreviation                                             AF                AL
# Agricultural Land( %)                                58.10%            43.10%
# Land Area(Km2)                                      652,230            28,748
# Armed Forces size                                   323,000             9,000
# Birth Rate                                            32.49             11.78
# Calling Code                                           93.0             355.0
# Capital/Major City                                    Kabul            Tirana
# Co2-Emissions                                         8,672             4,536
# CPI                                                   149.9            119.05
# ...

# %%
# Resumo do DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density(P/Km2)                             195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %% [markdown]
# O conjunto de dados composto por 195 entradas fornece uma representação abrangente de informações de todos os países. Esta extensa cobertura facilitará comparações e análises significativas, o que permitirá investigar a relação entre muitos aspectos dos países.

# %%
# Conta o número de elementos nulos em cada coluna
elementos_nulos = df.isnull().sum()

# Exibe o resultado
print("Número de elementos nulos em cada coluna:")
print(elementos_nulos)
# Out:
# Número de elementos nulos em cada coluna:
# Country                                       0
# Density(P/Km2)                                0
# Abbreviation                                  7
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# ...

# %%
# Retorna a porcentagem de elementos nulos em cada coluna
porcentagem_elementos_nulos = (df.isnull().mean()*100).round(2)

# Exibe o resultado
print("Porcentagem de elementos nulos em cada coluna:")
print(porcentagem_elementos_nulos)
# Out:
# Porcentagem de elementos nulos em cada coluna:
# Country                                       0.00
# Density(P/Km2)                                0.00
# Abbreviation                                  3.59
# Agricultural Land( %)                         3.59
# Land Area(Km2)                                0.51
# Armed Forces size                            12.31
# Birth Rate                                    3.08
# Calling Code                                  0.51
# Capital/Major City                            1.54
# Co2-Emissions                                 3.59
# CPI                                           8.72
# CPI Change (%)                                8.21
# Currency-Code                                 7.69
# Fertility Rate                                3.59
# Forested Area (%)                             3.59
# Gasoline Price                               10.26
# GDP                                           1.03
# ...

# %%
# Subdivisão do DataFrame em dois subconjuntos, com base nos dtypes da coluna

df_num1 = df.select_dtypes(include=[np.number])  # dtypes numérico (float)
df_num1 = df_num1.drop(columns=['Latitude', 'Longitude', 'Calling Code'])

df_cat1 = df.select_dtypes(include =[object])    # dtypes objeto

# %%
# Visualizando o Dataframe dtypes numérico
df_num1.head().T
# Out:
#                                0      1       2     3       4
# Birth Rate                 32.49  11.78   24.28  7.20   40.73
# Fertility Rate              4.47   1.62    3.02  1.27    5.52
# Infant mortality           47.90   7.80   20.10  2.70   51.60
# Life expectancy            64.50  78.50   76.70   NaN   60.80
# Maternal mortality ratio  638.00  15.00  112.00   NaN  241.00
# Physicians per thousand     0.28   1.20    1.72  3.33    0.21

# %%
# Gerando estatísticas descritivas: aquelas que resumem a tendência central, a dispersão e a forma da distribuição de um conjunto de dados, excluindo NaN valores.

df_cat1.describe().T
# Out:
#                                           count unique               top freq
# Country                                     195    195       Afghanistan    1
# Density(P/Km2)                              195    137                25    7
# Abbreviation                                188    188                AF    1
# Agricultural Land( %)                       188    168            17.40%    3
# Land Area(Km2)                              194    194           652,230    1
# Armed Forces size                           171    105             2,000    7
# Capital/Major City                          192    192             Kabul    1
# Co2-Emissions                               188    184               143    2
# CPI                                         178    175            110.62    2
# CPI Change (%)                              179     86             2.80%    7
# Currency-Code                               180    133               EUR   23
# ...

# %% [markdown]
# É possível observar que boa parte dessas colunas, embora estejam classificados como categóricos, deveriam estar classificadas como numéricas. Isso ocorre devido o uso de símbolos '$' e "%" e por usar "," em vez de ".".

# %% [markdown]
# ## 2 - Transformando os Dados

# %%
#ajuste das colunas numéricas que estão definidas como categóricas

transform_features = [ 'Agricultural Land( %)',  'Armed Forces size','Land Area(Km2)','Density(P/Km2)', 
'Forested Area (%)', 'Co2-Emissions','CPI', 'CPI Change (%)', 'Gasoline Price', 'GDP',
'Gross primary education enrollment (%)','Gross tertiary education enrollment (%)', 
'Minimum wage', 'Out of pocket health expenditure', 'Urban_population','Population: Labor force participation (%)',
'Population' ,'Tax revenue (%)', 'Unemployment rate','Total tax rate']

for column in transform_features:
    df[column]=df[column].astype(str)
    df[column]=df[column].str.replace(",","")
    df[column]=df[column].str.replace("$","")
    df[column]=df[column].str.replace("%","").astype(float)

import warnings     # Controle de avisos

warnings.filterwarnings('ignore') # Nunca exibe avisos correspondentes

# %%
#novas features

df["GDP_per_capita"]=df["GDP"]/df["Population"]
df["Rural_population"]=df["Population"]-df["Urban_population"]
df["urban_pop/total_pop"] = df["Urban_population"]/df["Population"]
df["rural_pop/total_pop"] = df["Rural_population"]/df["Population"]
df["Agricultural Land Area (Km2)"] = df["Land Area(Km2)"]*df['Agricultural Land( %)']

# %%
#unindo o dataset de continentes ao dataset de países

merged_df = pd.merge(df, continents_df, on='Abbreviation', how='left')
df = merged_df
df.T
# Out:
#                                                      0                  1    \
# Country                                      Afghanistan            Albania
# Density(P/Km2)                                      60.0              105.0
# Abbreviation                                          AF                 AL
# Agricultural Land( %)                               58.1               43.1
# Land Area(Km2)                                  652230.0            28748.0
# Armed Forces size                               323000.0             9000.0
# Birth Rate                                         32.49              11.78
# Calling Code                                        93.0              355.0
# Capital/Major City                                 Kabul             Tirana
# Co2-Emissions                                     8672.0             4536.0
# CPI                                                149.9             119.05
# ...

# %% [markdown]
# ## 3 - Estatísticas descritivas

# %%
# Subdivisão do DataFrame em dois subconjuntos, com base nos dtypes ajustados

df_num = df.select_dtypes(include=[np.number])  # dtypes numérico (float)
df_num = df_num.drop(columns=['Latitude', 'Longitude', 'Calling Code'])

df_cat = df.select_dtypes(include =[object])    # dtypes objeto

# %%
# Estatíticas descritivas para as colunas categóricas

df_cat.describe().T
# Out:
#                    count unique             top freq
# Country              195    195     Afghanistan    1
# Abbreviation         188    188              AF    1
# Capital/Major City   192    192           Kabul    1
# Currency-Code        180    133             EUR   23
# Largest city         189    188           S����    2
# Official language    190     76         English   31
# Continent            190      5          Africa   56
# Region               190     24  Western Africa   20

# %%
# Estatíticas descritivas para as colunas numéricas

df_num.describe()
# Out:
#        Density(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# count      195.000000             188.000000    1.940000e+02
# mean       356.764103              39.117553    6.896244e+05
# std       1982.888967              21.783052    1.921609e+06
# min          2.000000               0.600000    0.000000e+00
# 25%         35.500000              21.700000    2.382825e+04
# 50%         89.000000              39.600000    1.195110e+05
# 75%        216.500000              55.375000    5.242560e+05
# max      26337.000000              82.600000    1.709824e+07
#
#        Armed Forces size  Birth Rate  Co2-Emissions          CPI  \
# count       1.710000e+02  189.000000   1.880000e+02   178.000000
# mean        1.592749e+05   20.214974   1.777992e+05   190.460955
# std         3.806288e+05    9.945774   8.387903e+05   397.947380
# min         0.000000e+00    5.900000   1.100000e+01    99.030000
# 25%         1.100000e+04   11.300000   2.304250e+03   113.885000
# ...

# %% [markdown]
# Analise de medidas agrupando por continente

# %%
# Taxa de fertilidade

birth_rate_desc = df.groupby('Continent')['Fertility Rate'].describe()
birth_rate_desc
# Out:
#            count      mean       std   min     25%   50%    75%   max
# Continent
# Africa      52.0  4.111346  1.169050  1.41  3.3825  4.32  4.750  6.91
# Americas    35.0  2.098286  0.383877  1.44  1.7500  2.06  2.410  2.94
# Asia        47.0  2.303191  0.734433  0.98  1.8700  2.09  2.775  4.47
# Europe      37.0  1.502973  0.168603  1.23  1.3700  1.52  1.620  1.88
# Oceania     12.0  3.190000  0.899262  1.71  2.6300  3.56  3.805  4.40

# %%
#Indice de Preço ao Consumidor

cpi_desc = df.groupby('Continent')['CPI'].describe()
cpi_desc
# Out:
#            count        mean         std     min       25%      50%       75%  \
# Continent
# Africa      50.0  186.151000  178.386466  103.62  114.4000  150.420  184.9000
# Americas    34.0  217.390588  447.518717  103.87  116.1975  133.000  149.8350
# Asia        44.0  150.779318   68.847252   99.03  117.0375  131.815  164.4350
# Europe      34.0  120.725882   30.380765   99.55  110.6225  114.755  118.8825
# Oceania     11.0  121.908182   14.524595   99.55  115.6850  118.170  126.6950
#
#                max
# Continent
# Africa     1344.19
# Americas   2740.27
# Asia        550.93
# Europe      281.66
# Oceania     155.99

# %%
#PIB

gdp_desc = df.groupby('Continent')['GDP'].describe()
gdp_desc
# Out:
#            count          mean           std           min           25%  \
# Continent
# Africa      54.0  5.152409e+10  9.889408e+10  4.290166e+08  4.136288e+09
# Americas    35.0  8.232389e+11  3.614239e+12  5.960333e+08  4.744722e+09
# Asia        47.0  8.368407e+11  2.975495e+12  2.446674e+09  2.700190e+10
# Europe      38.0  5.115262e+11  8.893385e+11  1.637931e+09  3.206951e+10
# Oceania     14.0  1.167886e+11  3.712850e+11  4.727146e+07  2.369572e+08
#
#                     50%           75%           max
# Continent
# Africa     1.413218e+10  3.878840e+10  4.481204e+11
# Americas   3.814529e+10  1.671419e+11  2.142770e+13
# Asia       7.698309e+10  3.859471e+11  1.991000e+13
# Europe     1.573741e+11  5.087837e+11  3.845630e+12
# Oceania    6.505042e+08  4.507930e+09  1.392681e+12

# %%
# Mortalidade Infantil

mor_inf_desc = df.groupby('Continent')['Infant mortality'].describe()
mor_inf_desc
# Out:
#            count       mean        std  min    25%    50%     75%   max
# Continent
# Africa      52.0  41.678846  19.186477  3.1  29.75  39.05  53.625  84.5
# Americas    35.0  14.468571   8.883884  3.7   9.30  12.40  16.650  49.5
# Asia        47.0  16.523404  13.204647  1.8   6.60  12.40  23.250  57.2
# Europe      37.0   3.732432   2.276700  1.4   2.60   3.30   3.800  13.6
# Oceania     13.0  20.400000  11.142561  3.1  13.60  20.60  25.600  41.2

# %%
# Expectativa de Vida

exp_vid_desc = df.groupby('Continent')['Life expectancy'].describe()
exp_vid_desc
# Out:
#            count       mean       std   min     25%    50%    75%   max
# Continent
# Africa      52.0  64.388462  6.495871  52.8  60.800  63.80  66.95  82.3
# Americas    35.0  75.051429  3.463794  63.7  73.250  75.00  77.00  81.9
# Asia        47.0  74.076596  4.726991  64.5  71.000  73.60  77.10  84.2
# Europe      36.0  79.627778  3.528303  71.6  77.275  81.15  82.35  85.4
# Oceania     12.0  71.125000  5.866720  64.3  67.675  69.70  72.90  82.7

# %%
# Mortalidade Materna

mort_mae_desc = df.groupby('Continent')['Maternal mortality ratio'].describe()
mort_mae_desc
# Out:
#            count        mean         std   min     25%    50%     75%     max
# Continent
# Africa      52.0  389.384615  271.008874   5.0  208.50  338.5  545.00  1140.0
# Americas    33.0   80.151515   82.940913  10.0   36.00   65.0   95.00   480.0
# Asia        47.0   73.531915  106.917654   3.0   16.50   29.0  105.00   638.0
# Europe      34.0    7.470588    5.200439   2.0    4.00    5.5    8.75    19.0
# Oceania     10.0   64.500000   44.041016   6.0   36.25   62.0   91.00   145.0

# %%
# Médicos por mil habitantes

med_mil_desc = df.groupby('Continent')['Physicians per thousand'].describe()
med_mil_desc
# Out:
#            count      mean       std   min    25%   50%    75%   max
# Continent
# Africa      52.0  0.427885  0.672130  0.01  0.080  0.15  0.405  3.31
# Americas    35.0  2.048000  1.550669  0.23  1.165  1.59  2.555  8.42
# Asia        47.0  1.961702  1.420297  0.17  0.815  1.88  2.510  7.12
# Europe      37.0  3.805405  1.159259  1.20  3.010  3.61  4.250  6.56
# Oceania     13.0  0.946154  1.239688  0.07  0.190  0.42  0.920  3.68

# %%
# Força de trabalho

trab_desc = df.groupby('Continent')['Population: Labor force participation (%)'].describe()
trab_desc
# Out:
#            count       mean        std   min     25%    50%    75%   max
# Continent
# Africa      51.0  64.774510  12.542374  41.2  56.500  67.80  75.40  86.1
# Americas    31.0  64.490323   5.618087  51.1  61.650  65.10  67.15  77.6
# Asia        47.0  62.619149  12.219757  38.0  54.750  64.00  69.30  86.8
# Europe      34.0  58.417647   6.136649  43.1  55.175  58.95  62.05  75.0
# Oceania      8.0  62.175000  13.039473  43.7  55.000  62.65  69.90  83.8

# %%
# Distribuição Força de Trabalho
sns.histplot(data=df, x='Population: Labor force participation (%)', kde=True, alpha=0)
# Out:
# <Axes: xlabel='Population: Labor force participation (%)', ylabel='Count'>

# %% [markdown]
# ## 4 - Visualização de dados

# %%
# Usando pairplot para visualizar uma grande variedade de recursos para encontrar rapidamente aqueles que queremos analisar mais profundamente
sns.pairplot(df_num1)

# %%
# Outra forma de verificar a correação por meio do mapa de calor
sns.heatmap(df_num1.corr(),annot=True,cmap='RdYlBu')
# Out:
# <Axes: >

# %% [markdown]
# - Esses tipos de visualização, pairplot ou mapa de calor, nos dá uma ideia ampliada de algumas relações entre os atributos dos países. Aqui podemos ver, por exemplo, que o número de médicos por mil (Physicians per Thousand - PpT) pode estar correlacionado com maior esperança de vida (Life Expectancy), menor mortalidade infantil (Infant Mortality) e taxa de mortalidade materna (Maternal Mortality Ratio). Em algum momento, um bom número de médicos por mil (PpT) indica maior investimento em saúde, o que deve minimizar o número de mortes.

# %% [markdown]
# - Existem também outras relações interessantes, como a taxa de natalidade (Birth Rate - BR) vs PpT. Vemos que o número de BR tende a diminuir quando o PpT aumenta.

# %% [markdown]
# ### 4.1 - Visualização de dados com regressão simples

# %% [markdown]
# - Para mostrar rapidamente as relações entre os recursos, utilizaremos uma ferramenta de regressão simples da biblioteca Plotly. Com isso, selecionamos o método dos Mínimos Quadrados Ordinários (OLS) para fazer isso. Criaremos uma linha de tendência baseada em OLS e ela nos dará informações mais precisas sobre como essas características estão correlacionadas e quão bem a regressão descreve a relação entre elas. Resumindo, uma linha de tendência linear é criada para descrever o comportamento dos dados. Onde: Y=a∗X+b
#
# - Onde Y
#    é um recurso selecionado e X
#    outro. As constantes a
#    e b
#    pode nos informar sobre quão intensa é a relação entre os recursos.

# %% [markdown]
# #### 4.1.1 - Indicadores de saúde

# %%
# Relação entre médicos por mil, expectativa de vida e taxa de natalidade

plt = px.scatter(df, x="Physicians per thousand", y="Birth Rate", color = "Life expectancy", log_x="True", trendline="ols",
                 trendline_options=dict(log_x=True),color_continuous_scale="Spectral",hover_data=df[['Country']],
                 title="Taxa de Natalidade e Expectativa de Vida por Médicos por Mil")

plt.update_xaxes(title_text="Médicos por Mil (Mpm)")
plt.update_yaxes(title_text="Taxa de Natalidade")

plt.show()

# %% [markdown]
# - O valor de $R^2$ varia de 0 a 1, em que 1 afirma que o modelo descreve perfeitamente a relação entre as características. Os valores $R^2$ são calculados por:
# $$
#    R^2=1−\frac{Σ(y_i−y_{(tl)})^2}{Σ(y_i−y_{avg})^2}
# $$
#
# - Em que o $y_i$ são os pontos de dados y localização, $y_{tl}$ a linha de tendência e $y_{avg}$ o valor médio dos pontos.
#
# - Por este gráfico, podemos ver que os países com elevada taxa de natalidade e menor MpM são também os países com menor esperança de vida. Vale a pena analisar esses dados relacionados a indicadores econômicos, como o PIB per capita que criamos. O $R^2$ é muito bom, mostrando que o modelo está bem ajustado. Além disso, a curva é descrescente e o coeficiente $a$ da regressão é negativo, o que significa que a relação entre a Taxa de Natalidade e o MpM é inversamente proporcional.

# %%
plt = px.scatter(df, x="GDP_per_capita", y="Birth Rate", color = "Life expectancy",
                 trendline="ols", trendline_options=dict(log_x=True), color_continuous_scale="Spectral",hover_data=df[['Country']],
                 title="Taxa de Nascimento e Expectativa de Vida por PIB per capita")

plt.update_xaxes(title_text="PIB per capita")
plt.update_yaxes(title_text="Taxa de Natalidade")

plt.show()

# %% [markdown]
# - Como podemos ver neste gráfico, a expectativa de vida tende a aumentar em países com maior PIB per capita, o que indica populações ricas em média. Além disso, taxas de natalidade mais elevadas estão relacionadas com países com um menor PIB per capita e, como vimos nos gráficos anteriores, menos PpT. Portanto, o País de Baixa Renda pode não ter como investir em uma boa estrutura de saúde, o que pode resultar em Elevada Mortalidade Infantil e Materna. Aqui $R^2=0,69$ para Mortalidade Infantil e $R^2=0,63$ para Mortalidade Materna. O coeficiente $a$ ainda são negativos, indicando relação inversalmente proporcional.

# %%
fig = make_subplots(rows=2, cols=1)


plt2= px.scatter(df, x="Physicians per thousand", y="Infant mortality", color = "Life expectancy",
                 trendline="ols", trendline_options=dict(log_x=True), color_continuous_scale="Spectral", hover_data=df[['Country']])


fig.add_trace(go.Scatter(plt2.data[0]),row=1,col=1)
fig.add_trace(go.Scatter(plt2.data[1],line=dict(color='#EF553B')),row=1,col=1)

fig.update_yaxes(title_text="Mortalidade Infantil", row=1, col=1)

plt3= px.scatter(df, x="Physicians per thousand", y="Maternal mortality ratio", color = "Life expectancy",
                 trendline="ols", trendline_options=dict(log_x=True), color_continuous_scale="Spectral", hover_data=df[['Country']])


fig.add_trace(go.Scatter(plt3.data[0]),row=2,col=1)
fig.add_trace(go.Scatter(plt3.data[1],line=dict(color='#EF553B')),row=2,col=1)

fig.update_xaxes(title_text="Médicos por Mil (Mpm)", row=2, col=1)
fig.update_yaxes(title_text="Mortalidade Materna", row=2, col=1)

fig.show()

# %% [markdown]
# - O mesmo ocorre pros gráficos abaixo, agora relacionando a Mortalidede Infantil e Materna com o PIB per capita. Aqui $R^2=0,62$ para Mortalidade Infantil e $R^2=0,47$ para Mortalidade Materna. O coeficiente $a$ ainda são negativos, indicando relação inversalmente proporcional.

# %%
fig = make_subplots(rows=2, cols=1)


plt2= px.scatter(df, x="GDP_per_capita", y="Infant mortality", color = "Life expectancy",
                 trendline="ols", trendline_options=dict(log_x=True), color_continuous_scale="Spectral", hover_data=df[['Country']])


fig.add_trace(go.Scatter(plt2.data[0]),row=1,col=1)
fig.add_trace(go.Scatter(plt2.data[1],line=dict(color='#EF553B')),row=1,col=1)

fig.update_yaxes(title_text="Mortalidade Infantil", row=1, col=1)

plt3= px.scatter(df, x="GDP_per_capita", y="Maternal mortality ratio", color = "Life expectancy",
                 trendline="ols", trendline_options=dict(log_x=True), color_continuous_scale="Spectral", hover_data=df[['Country']])


fig.add_trace(go.Scatter(plt3.data[0]),row=2,col=1)
fig.add_trace(go.Scatter(plt3.data[1],line=dict(color='#EF553B')),row=2,col=1)

fig.update_xaxes(title_text="PIB per capita", row=2, col=1)
fig.update_yaxes(title_text="Taxa de mortalidade materna", row=2, col=1)

fig.show()

# %% [markdown]
# - Usamos o plotely choropleth para plotar um mapa mundi, o que permite uma visualização mais clara, objetiva e intuitiva. Esse tipo de plotagem é de fácil entendimento e nos permite tirar conclusões geográficas e até geopolíticas.
# - Podemos concluir que o número de médicos para cada mil habitantes pode estar relacionado à qualidade e ao investimento em saúde pelo país. Vemos que quanto menor o número de médicos, pior a qualidade da saúde do país. Nos próximos mapas, seguiremos analisando mais alguns dados relacionados a idicadores de saúde.

# %%
fig_medicos = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral",color='Physicians per thousand',projection='natural earth',
                   title='Médicos por Mil por País')
fig_medicos.show()

# %% [markdown]
# - No gráfico de expectativa de vida por país podemos notar que há um claro recorte continental, estando os países com baixa expectativa de vida concentrados no continente africano. Sendo que no norte da África há um melhoramento do indicador.

# %%
fig_exp_vida = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral",color='Life expectancy',
                    projection='natural earth', title='Expectativa de Vida por País')
fig_exp_vida.show()

# %% [markdown]
# - A mesma análise anterior pode ser notada no gráfico abaixo de taxa de natalidade por país.

# %%
#Taxa de Natalidade - Número de nascimentos por 1.000 habitantes por ano:
fig_taxa_natalidade = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral", color='Birth Rate',
                    projection='natural earth', title='Taxa de Natalidade por País')
fig_taxa_natalidade.show()

# %% [markdown]
# - Além de possuir uma menor quantidade de médicos por mil habitantes, os países da África e do Sul da Ásia possuem uma maior taxa de natalidade do que as outras regiões. Se seguirmos a lógica adotada anteriormente, países com poucos médicos e grandes taxas de natalidade possivelmente vão sofrer de maiores taxas de mortalidade infantil e maternal. Abaixo, tentaremos provar essa hipótese com novos mapas.

# %%
#Taxa de fertilidade - Número médio de filhos nascidos de uma mulher durante sua vida
fig_fertilidade = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral", color='Fertility Rate',
                    projection='natural earth', title='Taxa de Fertilidade por País')
fig_fertilidade.show()

# %%
#Mortalidade Infantil - Número de mortes por 1.000 nascidos vivos antes de completar um ano de idade.
fig_mort_inf = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral", color='Infant mortality',
                    projection='natural earth', title='Mortalidade infantil por país')
fig_mort_inf.show()

# %%
#Taxa de Mortalidade Materna - Número de mortes maternas por 100.000 nascidos vivos:
fig_mort_mae = px.choropleth(df, locations='Country', locationmode = "country names", hover_name='Country'
                   ,color_continuous_scale="Spectral", color='Maternal mortality ratio',
                    projection='natural earth', title='Mortalidade maternal por país')
fig_mort_mae.show()

# %% [markdown]
# #### 4.1.2 - Indicadores geoeconômicos

# %% [markdown]
# - Analisando as Emissões de CO2 em relação ao PIB temos um $R²=0,91$.

# %%
fig=px.scatter(df,x="GDP", y="Co2-Emissions",trendline="ols",log_y=True,log_x=True,trendline_options=dict(log_x=True,log_y=True),
               color = "Population", hover_data=df[['Country']],
               title="Emissões de CO2 e População por PIB")

fig.update_xaxes(title_text="PIB")
fig.update_yaxes(title_text="Emissões de CO2")

fig.show()

# %% [markdown]
# - É possível ver que pode ser que haja uma correlação entre a população e a Emissão de CO2. Para testar a hipótese, fizemos essa dispersão:

# %%
fig=px.scatter(df,x="Population", y="Co2-Emissions",trendline="ols",log_y=True,log_x=True,trendline_options=dict(log_x=True,log_y=True),
               hover_data=df[['Country']], title="Emissão de CO2 por População")

fig.update_xaxes(title_text="População")
fig.update_yaxes(title_text="Emissão de CO2")
 
fig.show()

# %% [markdown]
# - Essa dispersão retorna um $R²=0,64$. Para uma dispersão somente com a População Urbana, é possível observar que retorna uma reta com $R²=0,75$.

# %%
fig=px.scatter(df,x="Urban_population", y="Co2-Emissions",trendline="ols",log_x=True,log_y=True,trendline_options=dict(log_x=True,log_y=True),color = "Co2-Emissions",hover_data=df[['Country']])

fig.update_xaxes(title_text="População Urbana")
fig.update_yaxes(title_text="Emissão de CO2")

fig.show()

# %% [markdown]
# - Plotando um gráfico de barras dos top10 países que emitem mais CO2, é possível observar que a maioria apresentam uma alta taxa de população morando na zona urbana.
# - China (1º) e Indonésia (10º) apresentam uma boa distribuição entre a população urbana e rural.
# - Índia diverge e apresenta uma baixa taxa de população urbana.

# %%
#Selecionando os 10 países com a maior emissão de co2

top_10_co2 = df.nlargest(10, 'Co2-Emissions')

fig = px.bar(top_10_co2, y='Co2-Emissions', x='Country', text_auto='.2s', color ="urban_pop/total_pop",
             title="Emissão de Co2 e Taxa de população urbana (P/km²) por País")

fig.update_xaxes(title_text="País")
fig.update_yaxes(title_text="Emissão de CO2")

fig.show()

# %% [markdown]
# - Plotando um gráfico de barras dos 10 países com uma maior área territorial, é possível observar que a maioria apresentam uma baixa taxa de densidade populacional em relação a Índia (7º) e a China (4º).

# %%
#Selecionando os 10 países com maior área territorial

top_10_area_territorial = df.nlargest(10, 'Land Area(Km2)')

fig = px.bar(top_10_area_territorial, y='Land Area(Km2)', x='Country', text_auto='.2s', color ="Density(P/Km2)",
            title="Área territorial (km²) e Desindade Populacional (P/km²) por País")

fig.update_xaxes(title_text="País")
fig.update_yaxes(title_text="Área territorial (km²)")

fig.show()

# %% [markdown]
# - Plotando agora um grafo de barras relacionando a Área de Terra Agrícola (km²) e a Densidade populacional (P/km²) por país, é possível observar que os dados estão bem distribuídos, com a taxa de população rural entre 0,1 e 0,4, exceto pela Índia (7º) que apresentam uma taxa de 0,7.

# %%
#Selecionando os 10 países com maior área de terra agrícola
top_10_columns = df.nlargest(10, "Agricultural Land Area (Km2)")

#Analysing how this biggest areas are related with the Density rate
fig = px.bar(top_10_columns, y="Agricultural Land Area (Km2)", x='Country', text_auto='.2s', color ="rural_pop/total_pop",
            title="Área de Terra Agrícola (km2) e Desindade Populacional (P/km2) por País")

fig.update_xaxes(title_text="País")
fig.update_yaxes(title_text="Área de Terra Agrícola (km²)")

fig.show()
